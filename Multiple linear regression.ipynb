# %% [markdown]
# # Application

# %%
# https://archive.ics.uci.edu/ml/datasets/wine+quality

from sklearn.linear_model import LinearRegression
import pandas as pd
import matplotlib.pylab as plt
from sklearn.model_selection import train_test_split

df = pd.read_csv('./forestfires.csv')

# %%
# df.head()
df.tail()
# Out:
#      X  Y  FFMC    DMC     DC   ISI  temp  RH  wind  rain   area
# 512  4  3  81.6   56.7  665.6   1.9  27.8  32   2.7   0.0   6.44
# 513  2  4  81.6   56.7  665.6   1.9  21.9  71   5.8   0.0  54.29
# 514  7  4  81.6   56.7  665.6   1.9  21.2  70   6.7   0.0  11.16
# 515  1  4  94.4  146.0  614.7  11.3  25.6  42   4.0   0.0   0.00
# 516  6  3  79.5    3.0  106.7   1.1  11.8  31   4.5   0.0   0.00

# %%
df.describe()
# Out:
#                 X           Y        FFMC         DMC          DC         ISI  \
# count  517.000000  517.000000  517.000000  517.000000  517.000000  517.000000
# mean     4.669246    4.299807   90.644681  110.872340  547.940039    9.021663
# std      2.313778    1.229900    5.520111   64.046482  248.066192    4.559477
# min      1.000000    2.000000   18.700000    1.100000    7.900000    0.000000
# 25%      3.000000    4.000000   90.200000   68.600000  437.700000    6.500000
# 50%      4.000000    4.000000   91.600000  108.300000  664.200000    8.400000
# 75%      7.000000    5.000000   92.900000  142.400000  713.900000   10.800000
# max      9.000000    9.000000   96.200000  291.300000  860.600000   56.100000
#
#              temp          RH        wind        rain         area
# count  517.000000  517.000000  517.000000  517.000000   517.000000
# mean    18.889168   44.288201    4.017602    0.021663    12.847292
# ...

# %%
import matplotlib.pyplot as plt

fig, axs = plt.subplots(1,2, figsize=(15,3))
axs[0].scatter(df['temp'], df['FFMC'])
axs[0].set_xlabel('temp')
axs[0].set_ylabel('FFMC')
axs[0].set_title('temp Against FFMC')

axs[1].scatter(df['RH'], df['FFMC'])
axs[1].set_xlabel('RH')
axs[1].set_ylabel('FFMC')
axs[1].set_title('RH Against FFMC');

# %% [markdown]
# #1 the <b>temp</b> and <b>FFMC</b> is <b>weak positive</b> relationship;
# #2 <b>RH</b> and <b>FFMC</b> is <b>negative relationship</b>.

# %%
df['FFMC'].tail()
# Out:
# 512    81.6
# 513    81.6
# 514    81.6
# 515    94.4
# 516    79.5
# Name: FFMC, dtype: float64

# %%
from sklearn.linear_model import LinearRegression
import pandas as pd
import matplotlib.pylab as plt
from sklearn.model_selection import train_test_split
df = pd.read_csv('./forestfires.csv')
X = df[list(df.columns)[:-1]]
y = df['FFMC']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 1234)
regressor = LinearRegression()
regressor.fit(X_train, y_train)
y_predictions = regressor.predict(X_test)
print('R-squared: %s' % regressor.score(X_test, y_test))
# Out:
# R-squared: 1.0

# %%
X_test
# Out:
#      X  Y  FFMC    DMC     DC   ISI  temp  RH  wind  rain
# 496  4  5  96.2  175.5  661.8  16.8  32.6  26   3.1   0.0
# 263  6  3  91.1  141.1  629.1   7.1  19.3  39   3.6   0.0
# 213  7  3  87.6   52.2  103.8   5.0  11.0  46   5.8   0.0
# 296  6  4  90.4   89.5  290.8   6.4  14.3  46   1.8   0.0
# 67   2  2  92.4  117.9  668.0  12.2  19.6  33   5.4   0.0
# 66   2  2  92.4  117.9  668.0  12.2  23.0  37   4.5   0.0
# 494  6  6  96.0  164.0  643.0  14.0  30.8  30   4.9   0.0
# 21   5  4  91.8   78.5  724.3   9.2  19.1  38   2.7   0.0
# 309  2  4  92.4  105.8  758.1   9.9  24.9  27   2.2   0.0
# 381  8  6  90.7  194.1  643.0   6.8  16.2  63   2.7   0.0
# 287  7  4  91.6  104.2  474.9   9.0  22.1  49   2.7   0.0
# 407  4  5  84.7    8.2   55.0   2.9  14.2  46   4.0   0.0
# 111  3  4  91.7   33.3   77.5   9.0  18.8  18   4.5   0.0
# 262  2  4  91.6  112.4  573.0   8.9  21.4  42   3.1   0.0
# 255  2  5  87.5   77.0  694.8   5.0  22.3  46   4.0   0.0
# ...

# %%
y_predictions
# Out:
# array([96.2, 91.1, 87.6, 90.4, 92.4, 92.4, 96. , 91.8, 92.4, 90.7, 91.6,
#        84.7, 91.7, 91.6, 87.5, 92.1, 86.6, 88.2, 87.1, 87.2, 92.6, 92.5,
#        90.1, 91.6, 91.5, 93.1, 90.4, 90.2, 88.8, 94.8, 94.3, 92.8, 90.9,
#        93.9, 91.9, 91.6, 91.7, 84.4, 92.1, 91.4, 94.3, 81.9, 91.1, 93.5,
#        90.2, 91. , 91.7, 94.8, 92.1, 92.3, 93.1, 94.3, 93.7, 90.8, 96.1,
#        84.6, 87.6, 92.1, 84.4, 96.2, 95.2, 92.1, 91.3, 95.5, 79.5, 91. ,
#        75.1, 89.7, 85.1, 87.2, 92.4, 89.6, 92.5, 91.9, 92.2, 93.7, 93.7,
#        91. , 91.2, 84.9, 88.6, 91. , 92.6, 93.5, 91.5, 92.1, 93.3, 85.8,
#        90.9, 92.1, 91.1, 92.5, 90.9, 90.1, 91.4, 92.5, 93.7, 91.7, 94.9,
#        91. , 82.1, 53.4, 95.2, 92.1, 85. , 91.6, 91. , 94.3, 93.5, 94.8,
#        90.5, 91.2, 91.9, 93.4, 88.2, 86.2, 89.2, 95.2, 90.7, 96.1, 84.7,
#        90.7, 90.2, 93.7, 93.7, 90.1, 69. , 90.1, 91.6, 92.9])

# %%
import pandas as pd
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LinearRegression

df = pd.read_csv('./forestfires.csv')
X = df[list(df.columns)[:-1]]
y = df['FFMC']
regressor = LinearRegression()
scores = cross_val_score(regressor, X, y, cv=5)
print(scores.mean())
print(scores)
# Out:
# 1.0
# [1. 1. 1. 1. 1.]

# %%
plt.scatter(y_test, y_predictions)
plt.xlabel('True FFMC')
plt.ylabel('Predicted FFMC')
plt.title('Predicted Against True')
plt.show()

# %% [markdown]
# # Gradient escent 梯度下降法

# %%
import numpy as np
# from sklearn.datasets import load_boston
from sklearn.linear_model import SGDRegressor
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

df = pd.read_csv('./forestfires.csv')
X = df[list(df.columns)[:-1]]
y = np.array(df['FFMC'].tolist())
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.5, random_state = 1234)

# %%
X_scaler = StandardScaler()
y_scaler = StandardScaler()
X_train = X_scaler.fit_transform(X_train)
y_train = y_scaler.fit_transform(y_train.reshape(-1,1)).ravel()
# y_train = y_scaler.fit_transform(y_train.array.reshape(-1, 1)).ravel()
X_test = X_scaler.transform(X_test)
y_test = y_scaler.transform(y_test.reshape(-1,1)).ravel()
# y_test = y_scaler.transform(y_test.array.reshape(-1, 1)).ravel()
regressor = SGDRegressor()
scores = cross_val_score(regressor, X_train, y_train, cv=5)
print(f'Cross validation r-squared scores: {scores}')
print(f'Average cross validation r-squared score: {np.mean(scores)}')
regressor.fit(X_train, y_train)
print(f'Test set r-squared score {regressor.score(X_test, y_test)}')
# Out:
# Cross validation r-squared scores: [0.96743645 0.98060189 0.78644376 0.92766973 0.97579872]
# Average cross validation r-squared score: 0.927590109174911
# Test set r-squared score 0.9701460879998947
# D:\Anaconda\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDRegressor'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# ...

# %% [markdown]
# # Use the coef_ attribute returns the coefficients of the independent variables.

# %%
regressor.coef_
# Out:
# array([ 0.00894747, -0.0095649 ,  0.84388711,  0.04579669, -0.00096251,
#         0.11558091, -0.0099734 , -0.06596307,  0.00591324,  0.00276929])

# %%
print('the polynomial regression model is: ')
for i, coef in enumerate(regressor.coef_):
    print('{0:+}*x^{1} '.format(round(coef, 2),i), end = "")
# Out:
# the polynomial regression model is:
# +0.01*x^0 -0.01*x^1 +0.84*x^2 +0.05*x^3 -0.0*x^4 +0.12*x^5 -0.01*x^6 -0.07*x^7 +0.01*x^8 +0.0*x^9
